# %% [markdown]
# Stock Market API project
# https://rapidapi.com/alphavantage/api/alpha-vantage/playground/apiendpoint_20e61c64-81d9-4b0e-911c-7d14a85cc4b6

# %% [markdown]
# Load API Key
# import streamlit as st
# api_key = st.secrets["API_KEY"]

# %% [markdown]
# Search Endpoint
#
# import requests
#
# url = "https://alpha-vantage.p.rapidapi.com/query"
#
# querystring = {"datatype":"json","keywords":"microsoft","function":"SYMBOL_SEARCH"}
#
# headers = {
# 	"x-rapidapi-key": "12bbfb2526mshaf85b113fe4ed1dp166522jsn2f02f33b5463",
# 	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
# }
#
# response = requests.get(url, headers=headers, params=querystring)
#
# print(response.json())
